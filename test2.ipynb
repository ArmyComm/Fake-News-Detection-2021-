# %%
import pandas as pd
import tensorflow as tf
import os
import re
import numpy as np
from string import punctuation
from zipfile import ZipFile
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
PATH='/content/gdrive/My Drive/ML Project/train.csv'

# %%
data = pd.read_csv(PATH)
print('총 샘플의 수 :',len(data))
train_data=data.copy()
train_data['title'].nunique(), data['text'].nunique() #기사제목, 기사내용 중복 내용 확인
# 윈도우 바탕화면에서 작업한 저자의 경우에는
# data = pd.read_csv(r'C:\Users\USER\Desktop\spam.csv',encoding='latin1')
train_data.drop_duplicates(subset=['text'], inplace=True) # v2 열에서 중복인 내용이 있다면 중복 제거
print('중복 제거 후 샘플의 수 :',len(train_data))
# Out:
# 총 샘플의 수 : 20800
# 중복 제거 후 샘플의 수 : 20387

# %%
# importing neural network libraries
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Embedding, GRU, LSTM, RNN, SpatialDropout1D
from tensorflow.keras.models import load_model

# %%
train_data = train_data.set_index('id', drop = True)

# %%
print(train_data.shape)
train_data.head()
# Out:
# (20387, 4)
#                                                 title  ... label
# id                                                     ...
# 0   House Dem Aide: We Didn’t Even See Comey’s Let...  ...     1
# 1   FLYNN: Hillary Clinton, Big Woman on Campus - ...  ...     0
# 2                   Why the Truth Might Get You Fired  ...     1
# 3   15 Civilians Killed In Single US Airstrike Hav...  ...     1
# 4   Iranian woman jailed for fictional unpublished...  ...     1
#
# [5 rows x 4 columns]

# %%
train_data.isnull().sum()
# Out:
# title      518
# author    1854
# text         1
# label        0
# dtype: int64

# %%
train_data[['title', 'author']] = train_data[['title', 'author']].fillna(value = 'Missing')
train_data = train_data.dropna()
train_data.isnull().sum()
# Out:
# title     0
# author    0
# text      0
# label     0
# dtype: int64

# %%
length = []
[length.append(len(str(text))) for text in train_data['text']]
train_data['length'] = length
train_data.head()
# Out:
#                                                 title  ... length
# id                                                     ...
# 0   House Dem Aide: We Didn’t Even See Comey’s Let...  ...   4930
# 1   FLYNN: Hillary Clinton, Big Woman on Campus - ...  ...   4160
# 2                   Why the Truth Might Get You Fired  ...   7692
# 3   15 Civilians Killed In Single US Airstrike Hav...  ...   3237
# 4   Iranian woman jailed for fictional unpublished...  ...    938
#
# [5 rows x 5 columns]

# %%
train_data = train_data.drop(train_data['text'][train_data['length'] < 50].index, axis = 0)
print('기사의 최대길이 : %d' % max(j for j in train_data['length']))
# Out:
# 기사의 최대길이 : 142961

# %%
max_features = 4500

# %%
tokenizer = Tokenizer(num_words = max_features, filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n', lower = True, split = ' ')
tokenizer.fit_on_texts(texts = train_data['text'])
X = tokenizer.texts_to_sequences(texts = train_data['text'])

# %%
print(X[20000])
# Out:
# [210, 145, 22, 438, 2, 38, 3377, 676, 86, 31, 19, 1, 1170, 5, 896, 20, 3126, 598, 28, 17, 817, 5, 630, 3, 1, 2749, 491, 3, 1, 732, 715, 1491, 17, 210, 145, 22, 438, 2, 21, 29, 1910, 20, 103, 1242, 3, 9, 1275, 580, 85, 55, 1, 823, 44, 22, 438, 2, 2712, 525, 3, 1, 48, 65, 17, 7, 1910, 145, 22, 966, 778, 236, 1, 205, 2, 147, 5, 2354, 37, 60, 28, 47, 967, 1401, 6, 1040, 7, 29, 2032, 311, 3, 210, 19, 1376, 676, 86, 31, 77, 24, 163, 1693, 896, 2, 70, 2965, 3844, 2, 567, 907, 1, 1170, 3, 38, 3377, 303, 817, 154, 1, 2023, 10, 586, 3595, 3, 27, 1230, 3, 3581, 70, 1231, 1046, 567, 1, 490, 1, 1170, 3, 1, 51, 8, 529, 49, 658, 4, 49, 58, 48, 145, 21, 7, 266, 485, 54, 5, 490, 221, 24, 163, 2, 21, 5, 33, 8, 43, 1170, 37, 1, 69, 3417, 49, 2, 179, 143, 12, 1, 8, 24, 122, 2, 22, 189, 9, 1, 823, 4, 99, 24, 122, 2, 22, 189, 9, 1, 2112, 224, 11, 48, 1329, 1314, 3403, 64, 5, 787, 1997, 1910, 8, 24, 86, 7, 91, 2, 48, 112, 151, 10, 97, 1095, 1997, 1, 823, 8, 24, 231, 5, 425, 119, 8, 5, 768, 337, 193, 20, 7, 1242, 6, 1, 14, 8, 24, 29, 1858, 337, 193, 485, 32, 134, 2062, 305, 2, 10, 1, 320, 3, 1, 490, 11, 21, 49, 722, 12, 684, 1119, 1020, 299, 1893, 21, 543, 63, 12, 49, 2089, 1095, 20, 1, 889, 3, 1, 8, 5, 131, 905, 1, 755, 3, 50, 6, 27, 141, 85, 97, 33, 203, 1910, 134, 1910, 8, 5, 936, 208, 252, 11, 41, 21, 1910, 10, 1471, 4, 52, 1, 41, 19, 1424, 2, 21, 19, 111, 75, 11, 16, 282]

# %%
X = pad_sequences(sequences = X, maxlen = max_features, padding = 'pre')
print(X.shape)
# Out:
# (20263, 4500)

# %%
print(X.shape)
y = train_data['label'].values
print(y.shape)
print(X)
m=len(X)
# Out:
# (20263, 4500)
# (20263,)
# [[   0    0    0 ... 1096    5 4201]
#  [   0    0    0 ... 3733  139 1166]
#  [   0    0    0 ...    3  207  671]
#  ...
#  [   0    0    0 ... 3741  778   11]
#  [   0    0    0 ...   10   59 3805]
#  [   0    0    0 ... 1565 2266 3643]]

# %%
n_of_train = int(len(X) * 0.8)
n_of_test = int(len(X) - n_of_train)

# %%
model = Sequential()
model.add(Embedding(m, 32))
model.add(LSTM(32))
model.add(Dense(1, activation='sigmoid'))

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=4)
mc = ModelCheckpoint('/content/gdrive/My Drive/ML Project/best_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)

# %%
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
history = model.fit(X, y, epochs=20, batch_size=10, callbacks=[es, mc], validation_split=0.2)
# Out:
# Epoch 1/20
# 1621/1621 [==============================] - ETA: 0s - loss: 0.2741 - acc: 0.8932
# Epoch 00001: val_acc improved from -inf to 0.93486, saving model to /content/gdrive/My Drive/ML Project/best_model.h5
# 1621/1621 [==============================] - 252s 155ms/step - loss: 0.2741 - acc: 0.8932 - val_loss: 0.1920 - val_acc: 0.9349
# Epoch 2/20
# 1621/1621 [==============================] - ETA: 0s - loss: 0.1554 - acc: 0.9445
# Epoch 00002: val_acc improved from 0.93486 to 0.94498, saving model to /content/gdrive/My Drive/ML Project/best_model.h5
# 1621/1621 [==============================] - 252s 156ms/step - loss: 0.1554 - acc: 0.9445 - val_loss: 0.1711 - val_acc: 0.9450
# Epoch 3/20
# 1621/1621 [==============================] - ETA: 0s - loss: 0
20
# 1621/1621 [==============================] - ETA: 0s - loss: 0.0639 - acc: 0.9798
# Epoch 00013: val_acc improved from 0.97360 to 0.97434, saving model to /content/gdrive/My Drive/ML Project/best_model.h5
# 1621/1621 [==============================] - 254s 157ms/step - loss: 0.0639 - acc: 0.9798 - val_loss: 0.0915 - val_acc: 0.9743
# Epoch 14/20
# 1621/1621 [==============================] - ETA: 0s - loss: 0.0535 - acc: 0.9832
# Epoch 00014: val_acc did not improve from 0.97434
# 1621/1621 [==============================] - 253s 156ms/step - loss: 0.0535 - acc: 0.9832 - val_loss: 0.1139 - val_acc: 0.9711
# Epoch 15/20
# 1621/1621 [==============================] - ETA: 0s - loss: 0.0501 - acc: 0.9856
# Epoch 00015: val_acc improved from 0.97434 to 0.97903, saving model to /content/gdrive/My Drive/ML Project/best_model.h5
# 1621/1621 [==============================] - 253s 156ms/step - loss: 0.0501 - acc: 0.9856 - val_loss: 0.0875 - val_acc: 0.9790
# Epoch 16/20
# 1621/1621 [==============================] - ETA: 0s - loss: 0.0447 - acc: 0.9867
# Epoch 00016: val_acc did not improve from 0.97903
# 1621/1621 [==============================] - 254s 157ms/step - loss: 0.0447 - acc: 0.9867 - val_loss: 0.1388 - val_acc: 0.9697
# Epoch 17/20
# 1621/1621 [==============================] - ETA: 0s - loss: 0.0470 - acc: 0.9866
# Epoch 00017: val_acc did not improve from 0.97903
# 1621/1621 [==============================] - 254s 157ms/step - loss: 0.0470 - acc: 0.9866 - val_loss: 0.0934 - val_acc: 0.9768
# Epoch 18/20
# 1621/1621 [==============================] - ETA: 0s - loss: 0.0419 - acc: 0.9871
# Epoch 00018: val_acc did not improve from 0.97903
# 1621/1621 [==============================] - 254s 157ms/step - loss: 0.0419 - acc: 0.9871 - val_loss: 0.0905 - val_acc: 0.9778
# Epoch 19/20
# 1621/1621 [==============================] - ETA: 0s - loss: 0.0435 - acc: 0.9869
# Epoch 00019: val_acc did not improve from 0.97903
# 1621/1621 [==============================] - 253s 156ms/step - loss: 0.0435 - acc: 0.9869 - val_loss: 0.1281 - val_acc: 0.9598
# Epoch 00019: early stopping

# %%
loaded_model = load_model('/content/gdrive/My Drive/ML Project/best_model.h5')
print("\n 테스트 정확도: %.4f" % (loaded_model.evaluate(X, y)[1]))
print(X.shape[1])
# Out:
# 634/634 [==============================] - 36s 56ms/step - loss: 0.0482 - acc: 0.9872
#
#  테스트 정확도: 0.9872
# 4500

# %%
print(X.shape[0])
# Out:
# 20263

# %%
import numpy as np
from numpy import argmax
loaded_model = load_model('/content/gdrive/My Drive/ML Project/best_model.h5')
##xhat = X[1]
##yhat = loaded_model.predict(xhat)
##print('Predict : ' + str(yhat))

xhat_idx = np.random.choice(X.shape[0], 5)
xhat = X[xhat_idx]
yhat = loaded_model.predict_classes(xhat)

for i in range(5):
    if(yhat[i]==0):
      print('Label : ' + str(argmax(y[xhat_idx[i]])) + ' Predict : True '+ str(yhat[i]))
    else:
      print('Label : ' + str(argmax(y[xhat_idx[i]])) + ' Predict : False '+ str(yhat[i]))
    ##print('Predict : ' + str(yhat[i]))
# Out:
# Label : 0 Predict : False [1]
# Label : 0 Predict : False [1]
# Label : 0 Predict : False [1]
# Label : 0 Predict : True [0]
# Label : 0 Predict : False [1]
