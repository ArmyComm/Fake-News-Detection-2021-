# %%
import pandas as pd
import tensorflow as tf
import os
import re
import numpy as np
from string import punctuation
from zipfile import ZipFile
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
PATH='/content/gdrive/My Drive/ML Project/train.csv'

# %%
data = pd.read_csv(PATH)
print('총 샘플의 수 :',len(data))
train_data=data.copy()
train_data['title'].nunique(), data['text'].nunique() #기사제목, 기사내용 중복 내용 확인
# 윈도우 바탕화면에서 작업한 저자의 경우에는
# data = pd.read_csv(r'C:\Users\USER\Desktop\spam.csv',encoding='latin1')
train_data.drop_duplicates(subset=['text'], inplace=True) # v2 열에서 중복인 내용이 있다면 중복 제거
print('중복 제거 후 샘플의 수 :',len(train_data))
# Out:
# 총 샘플의 수 : 20800
# 중복 제거 후 샘플의 수 : 20387

# %%
# importing neural network libraries
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Embedding, GRU, LSTM, RNN, SpatialDropout1D
from tensorflow.keras.models import load_model

# %%
train_data = train_data.set_index('id', drop = True)

# %%
print(train_data.shape)
train_data.head()
# Out:
# (20387, 4)
#                                                 title  ... label
# id                                                     ...
# 0   House Dem Aide: We Didn’t Even See Comey’s Let...  ...     1
# 1   FLYNN: Hillary Clinton, Big Woman on Campus - ...  ...     0
# 2                   Why the Truth Might Get You Fired  ...     1
# 3   15 Civilians Killed In Single US Airstrike Hav...  ...     1
# 4   Iranian woman jailed for fictional unpublished...  ...     1
#
# [5 rows x 4 columns]

# %%
train_data.isnull().sum()
# Out:
# title      518
# author    1854
# text         1
# label        0
# dtype: int64

# %%
train_data[['title', 'author']] = train_data[['title', 'author']].fillna(value = 'Missing')
train_data = train_data.dropna()
train_data.isnull().sum()
# Out:
# title     0
# author    0
# text      0
# label     0
# dtype: int64

# %%
length = []
[length.append(len(str(text))) for text in train_data['text']]
train_data['length'] = length
train_data.head()
# Out:
#                                                 title  ... length
# id                                                     ...
# 0   House Dem Aide: We Didn’t Even See Comey’s Let...  ...   4930
# 1   FLYNN: Hillary Clinton, Big Woman on Campus - ...  ...   4160
# 2                   Why the Truth Might Get You Fired  ...   7692
# 3   15 Civilians Killed In Single US Airstrike Hav...  ...   3237
# 4   Iranian woman jailed for fictional unpublished...  ...    938
#
# [5 rows x 5 columns]

# %%
train_data = train_data.drop(train_data['text'][train_data['length'] < 50].index, axis = 0)
print('기사의 최대길이 : %d' % max(j for j in train_data['length']))
# Out:
# 기사의 최대길이 : 142961

# %%
max_features = 4500

# %%
tokenizer = Tokenizer(num_words = max_features, filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n', lower = True, split = ' ')
tokenizer.fit_on_texts(texts = train_data['text'])
X = tokenizer.texts_to_sequences(texts = train_data['text'])

# %%
X = pad_sequences(sequences = X, maxlen = max_features, padding = 'pre')
print(X.shape)
# Out:
# (20263, 4500)

# %%
print(X.shape)
y = train_data['label'].values
print(y.shape)
print(X)
m=len(X)
# Out:
# (20263, 4500)
# (20263,)
# [[   0    0    0 ... 1096    5 4201]
#  [   0    0    0 ... 3733  139 1166]
#  [   0    0    0 ...    3  207  671]
#  ...
#  [   0    0    0 ... 3741  778   11]
#  [   0    0    0 ...   10   59 3805]
#  [   0    0    0 ... 1565 2266 3643]]

# %%
n_of_train = int(len(X) * 0.8)
n_of_test = int(len(X) - n_of_train)
print('훈련데이터 수: '+ str(n_of_train))
print('검증데이터 수: '+ str(n_of_test))
# train_test_split
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2, shuffle=True, stratify=y, random_state=1)
print(X_valid.shape)
print(y_valid.shape)
print(X_train.shape)
print(y_train.shape)
# Out:
# 훈련데이터 수: 16210
# 검증데이터 수: 4053
# (4053, 4500)
# (4053,)
# (16210, 4500)
# (16210,)

# %%
model = Sequential()
model.add(Embedding(4500, 32))
model.add(GRU(32))
model.add(Dense(1, activation='sigmoid'))

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=4)
mc = ModelCheckpoint('/content/gdrive/My Drive/ML Project/GRUbest_model2.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)

# %%
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
history = model.fit(X_train, y_train, epochs=30, batch_size=10, callbacks=[es, mc], validation_split=0.2)
# Out:
# Epoch 1/30
# 1297/1297 [==============================] - ETA: 0s - loss: 0.3167 - acc: 0.8822
# Epoch 00001: val_acc improved from -inf to 0.93738, saving model to /content/gdrive/My Drive/ML Project/GRUbest_model2.h5
# 1297/1297 [==============================] - 487s 376ms/step - loss: 0.3167 - acc: 0.8822 - val_loss: 0.1913 - val_acc: 0.9374
# Epoch 2/30
# 1297/1297 [==============================] - ETA: 0s - loss: 0.1897 - acc: 0.9355
# Epoch 00002: val_acc did not improve from 0.93738
# 1297/1297 [==============================] - 493s 380ms/step - loss: 0.1897 - acc: 0.9355 - val_loss: 0.2129 - val_acc: 0.9244
# Epoch 3/30
# 1297/1297 [==============================] - ETA: 0s - loss: 0.1506 - acc: 0.9507
# Epoch 00003: val_acc improved from 0.93738 to 0.94756, saving model to /content/gdrive/My Drive/ML Project/GRUbest_model2.h5
# 1297/1297 [==============================] - 489s 377ms/step - loss: 0.1506 - acc: 0.9507 - val_loss: 0.1518 - val_acc: 0.9476
# Epoch 4/30
# 1297/1297 [==============================] - ETA: 0s - loss: 0.1239 - acc: 0.9604
# Epoch 00004: val_acc improved from 0.94756 to 0.95682, saving model to /content/gdrive/My Drive/ML Project/GRUbest_model2.h5
# 1297/1297 [==============================] - 490s 378ms/step - loss: 0.1239 - acc: 0.9604 - val_loss: 0.1229 - val_acc: 0.9568
# Epoch 5/30
# 1297/1297 [==============================] - ETA: 0s - loss: 0.1015 - acc: 0.9687
# Epoch 00005: val_acc improved from 0.95682 to 0.95836, saving model to /content/gdrive/My Drive/ML Project/GRUbest_model2.h5
# 1297/1297 [==============================] - 491s 379ms/step - loss: 0.1015 - acc: 0.9687 - val_loss: 0.1257 - val_acc: 0.9584
# Epoch 6/30
# 1297/1297 [==============================] - ETA: 0s - loss: 0.0861 - acc: 0.9719
# Epoch 00006: val_acc improved from 0.95836 to 0.96823, saving model to /content/gdrive/My Drive/ML Project/GRUbest_model2.h5
# 1297/1297 [==============================] - 490s 378ms/step - loss: 0.0861 - acc: 0.9719 - val_loss: 0.0915 - val_acc: 0.9682
# Epoch 7/30
# 1297/1297 [==============================] - ETA: 0s - loss: 0.0751 - acc: 0.9754
# Epoch 00007: val_acc improved from 0.96823 to 0.97224, saving model to /content/gdrive/My Drive/ML Project/GRUbest_model2.h5
# 1297/1297 [==============================] - 494s 381ms/step - loss: 0.0751 - acc: 0.9754 - val_loss: 0.0913 - val_acc: 0.9722
# Epoch 8/30
# 1297/1297 [==============================] - ETA: 0s - loss: 0.0687 - acc: 0.9783
# Epoch 00008: val_acc did not improve from 0.97224
# 1297/1297 [==============================] - 490s 378ms/step - loss: 0.0687 - acc: 0.9783 - val_loss: 0.0944 - val_acc: 0.9670
# Epoch 9/30
# 1297/1297 [==============================] - ETA: 0s - loss: 0.0615 - acc: 0.9806
# Epoch 00009: val_acc did not improve from 0.97224
# 1297/1297 [==============================] - 490s 378ms/step - loss: 0.0615 - acc: 0.9806 - val_loss: 0.0919 - val_acc: 0.9716
# Epoch 10/30
# 1297/1297 [==============================] - ETA: 0s - loss: 0.0536 - acc: 0.9821
# Epoch 00010: val_acc improved from 0.97224 to 0.97255, saving model to /content/gdrive/My Drive/ML Project/GRUbest_model2.h5
# 1297/1297 [==============================] - 489s 377ms/step - loss: 0.0536 - acc: 0.9821 - val_loss: 0.0791 - val_acc: 0.9725
# Epoch 11/30
# 1297/1297 [==============================] - ETA: 0s - loss: 0.0486 - acc: 0.9835
# Epoch 00011: val_acc did not improve from 0.97255
# 1297/1297 [==============================] - 488s 377ms/step - loss: 0.0486 - acc: 0.9835 - val_loss: 0.0836 - val_acc: 0.9698
# Epoch 12/30
# 1297/1297 [==============================] - ETA: 0s - loss: 0.0433 - acc: 0.9860
# Epoch 00012: val_acc improved from 0.97255 to 0.97903, saving model to /content/gdrive/My Drive/ML Project/GRUbest_model2.h5
# 1297/1297 [==============================] - 489s 377ms/step - loss: 0.0433 - acc: 0.9860 - val_loss: 0.0678 - val_acc: 0.9790
# Epoch 13/30
# 1297/1297 [==============================] - ETA: 0s - loss: 0.0406 - acc: 0.9881
# Epoch 00013: val_acc did not improve from 0.97903
# 1297/1297 [==============================] - 489s 377ms/step - loss: 0.0406 - acc: 0.9881 - val_loss: 0.0697 - val_acc: 0.9784
# Epoch 14/30
# 1297/1297 [==============================] - ETA: 0s - loss: 0.0383 - acc: 0.9885
# Epoch 00014: val_acc did not improve from 0.97903
# 1297/1297 [==============================] - 488s 377ms/step - loss: 0.0383 - acc: 0.9885 - val_loss: 0.0778 - val_acc: 0.9747
# Epoch 15/30
# 1297/1297 [==============================] - ETA: 0s - loss: 0.0349 - acc: 0.9890
# Epoch 00015: val_acc did not improve from 0.97903
# 1297/1297 [==============================] - 490s 378ms/step - loss: 0.0349 - acc: 0.9890 - val_loss: 0.0972 - val_acc: 0.9735
# Epoch 16/30
# 1297/1297 [==============================] - ETA: 0s - loss: 0.0319 - acc: 0.9902
# Epoch 00016: val_acc did not improve from 0.97903
# 1297/1297 [==============================] - 491s 379ms/step - loss: 0.0319 - acc: 0.9902 - val_loss: 0.0701 - val_acc: 0.9787
# Epoch 00016: early stopping

# %%
##loaded_model = load_model('/content/gdrive/My Drive/ML Project/GRUbest_model.h5')
loaded_model = load_model('/content/gdrive/My Drive/ML Project/GRUbest_model2.h5')
print("\n 테스트 정확도: %.4f" % (loaded_model.evaluate(X_valid, y_valid)[1]))
# Out:
# 127/127 [==============================] - 29s 230ms/step - loss: 0.0748 - acc: 0.9761
#
#  테스트 정확도: 0.9761

# %%
import numpy as np
from numpy import argmax
loaded_model = load_model('/content/gdrive/My Drive/ML Project/GRUbest_model2.h5')
##xhat = X[1]
##yhat = loaded_model.predict(xhat)
##print('Predict : ' + str(yhat))

n=50

xhat_idx = np.random.choice(X_valid.shape[0], n)
xhat = X_valid[xhat_idx]
yhat = loaded_model.predict_classes(xhat)

print(X_valid.shape, y_valid.shape)

for i in range(n):
    if(yhat[i]==0):
      print('Index: ' + str(xhat_idx[i]) + ' Label : ' + str(y_valid[xhat_idx[i]]) + ' Predict : True '+ str(yhat[i]))
    else:
      print('Index: ' + str(xhat_idx[i]) + ' Label : ' + str(y_valid[xhat_idx[i]]) + ' Predict : False '+ str(yhat[i]))

    ##print('Predict : ' + str(yhat[i]))

##if(y_valid[xhat_idx[0]]==yhat[0]):
   ## print("same")
# Out:
# (4053, 4500) (4053,)
# Index: 1298 Label : 0 Predict : True [0]
# Index: 1266 Label : 0 Predict : True [0]
# Index: 2474 Label : 0 Predict : True [0]
# Index: 1478 Label : 1 Predict : True [0]
# Index: 1577 Label : 1 Predict : False [1]
# Index: 192 Label : 0 Predict : True [0]
# Index: 884 Label : 1 Predict : False [1]
# Index: 597 Label : 0 Predict : True [0]
# Index: 3238 Label : 0 Predict : True [0]
# Index: 1386 Label : 0 Predict : True [0]
# Index: 90 Label : 1 Predict : False [1]
# Index: 3551 Label : 1 Predict : False [1]
# Index: 1186 Label : 0 Predict : True [0]
# Index: 3675 Label : 0 Predict : True [0]
# Index: 3413 Label : 0 Predict : True [0]
# Index: 3717 Label : 1 Predict : False [1]
# Index: 2060 Label : 0 Predict : True [0]
# Index: 278 Label : 1 Predict : False [1]
# Index: 86 Label : 1 Predict : False [1]
# Index: 2015 Label : 0 Predict : True [0]
# Index: 3123 Label : 0 Predict : True [0]
# Index: 2806 Label : 1 Predict : False [1]
# Index: 2211 Label : 1 Predict : False [1]
# Index: 2869 Label : 1 Predict : False [1]
# Index: 400 Label : 1 Predict : False [1]
# Index: 1856 Label : 1 Predict : False [1]
# Index: 2906 Label : 1 Predict : False [1]
# Index: 442 Label : 1 Predict : False [1]
# Index: 3514 Label : 1 Predict : False [1]
# Index: 3868 Label : 1 Predict : False [1]
# Index: 1478 Label : 1 Predict : True [0]
# Index: 3708 Label : 1 Predict : False [1]
# Index: 3780 Label : 1 Predict : False [1]
# Index: 2529 Label : 1 Predict : False [1]
# Index: 3799 Label : 0 Predict : True [0]
# Index: 3495 Label : 0 Predict : True [0]
# Index: 187 Label : 0 Predict : True [0]
# Index: 3325 Label : 0 Predict : True [0]
# Index: 2045 Label : 0 Predict : True [0]
# Index: 2790 Label : 1 Predict : False [1]
# Index: 207 Label : 1 Predict : False [1]
# Index: 1285 Label : 1 Predict : False [1]
# Index: 2621 Label : 0 Predict : True [0]
# Index: 3956 Label : 0 Predict : True [0]
# Index: 2486 Label : 1 Predict : False [1]
# Index: 3605 Label : 1 Predict : False [1]
# Index: 2011 Label : 0 Predict : True [0]
# Index: 2950 Label : 0 Predict : True [0]
# Index: 2691 Label : 1 Predict : False [1]
# Index: 2866 Label : 1 Predict : False [1]
